# %%
import pandas as pd 
import os
import glob

# %%
path = "D:/Resource/Data/CSV/Weather/Hourly"
csv_files = glob.glob(os.path.join(path, "*.csv"))

# %%
# loop over the list of csv files
for f in csv_files:
      
    # read the csv file
    df = pd.read_csv(f)
      
    # print the location and filename
    print('Location:', f)
    print('File Name:', f.split("\\")[-1])
      
    # print the content
    print('Content:')
    display(df)
    print()
# Out:
# Location: D:/Resource/Data/CSV/Weather/Hourly\en_climate_hourly_QC_702S006_01-2019_P1H.csv
# File Name: en_climate_hourly_QC_702S006_01-2019_P1H.csv
# Content:
#      Longitude (x)  Latitude (y)                          Station Name  \
# 0           -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 1           -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 2           -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 3           -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 4           -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# ..             ...           ...                                   ...
# 739         -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 740         -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 741         -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 742         -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# ...

# %%
data = pd.read_csv('C:/Users/asady/OneDrive - polymtl.ca/Data/Resource/Material/Raw Data/Weather/Hourly2020.csv', sep=";")
data.head(50)
# Out:
#             date_time_local  pressure_station  pressure_sea wind_dir  \
# 0   2020-12-31 23:00:00 EST            102.57        103.01      WSW
# 1   2020-12-31 22:00:00 EST            102.47        102.91        W
# 2   2020-12-31 21:00:00 EST            102.36        102.80      WSW
# 3   2020-12-31 20:00:00 EST            102.28        102.71       NW
# 4   2020-12-31 19:00:00 EST            102.17        102.60       NW
# 5   2020-12-31 18:00:00 EST            102.08        102.51       NW
# 6   2020-12-31 17:00:00 EST            101.96        102.39      WNW
# 7   2020-12-31 16:00:00 EST            101.85        102.28      WNW
# 8   2020-12-31 15:00:00 EST            101.69        102.12      WNW
# 9   2020-12-31 14:00:00 EST            101.53        101.96      WNW
# 10  2020-12-31 13:00:00 EST            101.43        101.85      WNW
# 11  2020-12-31 12:00:00 EST            101.34        101.76        W
# 12  2020-12-31 11:00:00 EST            101.27        101.69        W
# ...

# %%
df.to_csv("C:/Users/asady/OneDrive - polymtl.ca/Data/Resource/Material/Raw Data/Weather/Hourly2020_Precipitation.csv")
