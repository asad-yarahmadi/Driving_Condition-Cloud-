# %%
from pyclustertend import ivat
from sklearn.preprocessing import scale
import pandas as pd
from pyclustertend import hopkins
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('C:/Users/asady/OneDrive - polymtl.ca/Data/Resource/Material/Raw Data/Weather/Hourly27092021.csv')
del df['Unnamed: 0']

# %%
data = scale(df)
ivat(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25588/2328563554.py in <module>
#       1 data = scale(df)
# ----> 2 ivat(data)
#
# ~\.conda\envs\Gower\lib\site-packages\pyclustertend\visual_assessment_of_tendency.py in ivat(data, return_odm, figure_size)
#     153     """
#     154
# --> 155     ordered_matrix = compute_ivat_ordered_dissimilarity_matrix(data)
#     156
#     157     _, ax = plt.subplots(figsize=figure_size)
#
# ~\.conda\envs\Gower\lib\site-packages\pyclustertend\visual_assessment_of_tendency.py in compute_ivat_ordered_dissimilarity_matrix(x)
#     181     """
#     182
# --> 183     ordered_matrix = compute_ordered_dissimilarity_matrix(x)
#     184     re_ordered_matrix = np.zeros((ordered_matrix.shape[0], ordered_matrix.shape[0]))
#     185
#
# ~\.conda\envs\Gower\lib\site-packages\pyclustertend\visual_assessment_of_tendency.py in compute_ordered_dissimilarity_matrix(x)
#      99         for candidate_p in observation_path:
#     100             for candidate_j in J:
# --> 101                 if matrix_of_pairwise_distance[candidate_p, candidate_j] < mini:
#     102                     p = candidate_p
#     103                     q = candidate_j
#
# KeyboardInterrupt:

# %%
hopkins(df,150)
# Out:
# 0.001357294777983776

# %%
df.columns
# Out:
# Index(['pressure_station', 'pressure_sea', 'wind_dir_10s', 'wind_speed',
#        'relative_humidity', 'dew_point', 'temperature', 'visibility',
#        'max_air_temp_pst1hr', 'min_air_temp_pst1hr'],
#       dtype='object')

# %%
# Increase the size of the heatmap.
plt.figure(figsize=(16, 6))
# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
del df['pressure_sea']
del df['dew_point']
del df['max_air_temp_pst1hr']
del df['min_air_temp_pst1hr']

# %%
df.columns
# Out:
# Index(['pressure_station', 'wind_dir_10s', 'wind_speed', 'relative_humidity',
#        'temperature', 'visibility'],
#       dtype='object')

# %%
hopkins(df,50)
# Out:
# 0.001389414243831553

# %%
# Increase the size of the heatmap.
plt.figure(figsize=(16, 6))
# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
ivat(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25588/393652479.py in <module>
# ----> 1 ivat(df)
#
# ~\.conda\envs\Gower\lib\site-packages\pyclustertend\visual_assessment_of_tendency.py in ivat(data, return_odm, figure_size)
#     153     """
#     154
# --> 155     ordered_matrix = compute_ivat_ordered_dissimilarity_matrix(data)
#     156
#     157     _, ax = plt.subplots(figsize=figure_size)
#
# ~\.conda\envs\Gower\lib\site-packages\pyclustertend\visual_assessment_of_tendency.py in compute_ivat_ordered_dissimilarity_matrix(x)
#     181     """
#     182
# --> 183     ordered_matrix = compute_ordered_dissimilarity_matrix(x)
#     184     re_ordered_matrix = np.zeros((ordered_matrix.shape[0], ordered_matrix.shape[0]))
#     185
#
# ~\.conda\envs\Gower\lib\site-packages\pyclustertend\visual_assessment_of_tendency.py in compute_ordered_dissimilarity_matrix(x)
#      99         for candidate_p in observation_path:
#     100             for candidate_j in J:
# --> 101                 if matrix_of_pairwise_distance[candidate_p, candidate_j] < mini:
#     102                     p = candidate_p
#     103                     q = candidate_j
#
# KeyboardInterrupt:
